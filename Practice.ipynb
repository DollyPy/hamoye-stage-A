# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
data1 = np.array([[2,3, 4], [5,6,7]])

data1[:2, 1:]
# Out:
# array([[3, 4],
#        [6, 7]])

# %%
data = pd.read_csv("fuel_ferc1.csv")
data.shape
# Out:
# (29523, 11)

# %%
ds = (1,2)
ds[0]= 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-d367c3321cef> in <module>
#       1 ds = (1,2)
# ----> 2 ds[0]= 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
data.isnull()
# Out:
#        record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# 0          False             False        False             False
# 1          False             False        False             False
# 2          False             False        False             False
# 3          False             False        False             False
# 4          False             False        False             False
# ...          ...               ...          ...               ...
# 29518      False             False        False             False
# 29519      False             False        False             False
# 29520      False             False        False             False
# 29521      False             False        False             False
# 29522      False             False        False             False
#
#        fuel_type_code_pudl  fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                    False      False            False                False
# ...

# %%
newData = data.groupby("fuel_unit")
newData.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-55aa58307196> in <module>
#       1 newData = data.groupby("fuel_unit")
# ----> 2 newData.isnull().sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'isnull'

# %%
food = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
food.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
sum_data = food.groupby("Item")

# %%
# What is the total sum of Animal Fat produced in 2014 and 2017 respectively?
sum_data["Y2014", "Y2017"].sum()
# Out:
# <ipython-input-44-24e9a532bdad>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_data["Y2014", "Y2015", "Y2016", "Y2017"].sum()
#                          Y2014      Y2015      Y2016      Y2017
# Item
# Alcohol, Non-Food      2403.00    2180.00    2223.00    2348.00
# Alcoholic Beverages  102410.11   98783.72   96958.75   95581.06
# Animal Products       11935.65   11811.73   11661.69   11547.65
# Animal fats          209460.54  200675.72  183314.22  269617.53
# Apples and products    9499.23   10559.15    9853.26   10198.90
# ...                        ...        ...        ...        ...
# Vegetables, Other    155038.96  158104.08  156218.90  157752.59
# Vegetal Products     107145.19  107064.17  106792.72  107655.20
# Wheat and products   232670.13  234710.51  239377.07  240047.62
# Wine                   4497.36    4251.81    3872.09    4178.02
# ...

# %%
#2015 Stadard deviation and Mean
food.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#Missing Data
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#Correlation
food.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
#2017 What year has the highest sum of Import Quantity?

#2014 What is the total number of the sum of Production in 2014?

# %%
# Import quantity 
imp = food.groupby("Element")

imp.sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
imp["Element", "Y2018"].sum()
# Out:
# <ipython-input-50-813b99bbc4aa>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   imp["Element", "Y2018"].sum()
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# ...

# %%
food.groupby(["Area", "Element"])["Area", "Element", "Y2018"].sum().loc["Algeria"]
# Out:
# <ipython-input-55-01429f9a0ca9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food.groupby(["Area", "Element"])["Area", "Element", "Y2018"].sum().loc["Algeria"]
#                                            Y2018
# Element
# Domestic supply quantity                90023.42
# Export Quantity                           811.54
# Fat supply quantity (g/capita/day)        309.09
# Feed                                    10668.00
# Food                                    63736.33
# Food supply (kcal/capita/day)           13288.00
# Food supply quantity (kg/capita/yr)      1509.28
# Import Quantity                         36238.29
# Losses                                   7708.00
# Other uses (non-food)                    3970.08
# Processing                               2479.00
# Production                              60766.67
# Protein supply quantity (g/capita/day)    367.28
# ...

# %%
food["Area"].nunique()
# Out:
# 49
